# %%
#BLUEPRINT NOTEBOOK FOR EDS DATA ANALYSIS, NWA817 PYROXENE & LAFAYETTE OL

# %%
# %matplotlib notebook

# %%
import hyperspy.api as hs
import os
from hyperspy.drawing._widgets.scalebar import ScaleBar
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from mpl_toolkits.axes_grid1.anchored_artists import AnchoredSizeBar
import matplotlib.font_manager as fm
import matplotlib.patheffects as patheffects
import matplotlib
import matplotlib.patches as patches
import scipy.misc

# %%
#File paths for NWA817 Px. (x3 EDS spectra) and Lafayette Ol. (x1) Both from Nov. Session
#C:/Users/nt229/Jupyter/Diamond_Data/DLS_2022-11-22_14-50-20/mg31953-3/raw/raw/NWA817_pyroxine_grid_b5/NWA817_1
#C:/Users/nt229/Jupyter/Diamond_Data/DLS_2022-11-22_14-50-20/mg31953-3/raw/raw/NWA817_pyroxine_grid_b5/NWA817_2
#C:/Users/nt229/Jupyter/Diamond_Data/DLS_2022-11-22_14-50-20/mg31953-3/raw/raw/NWA817_pyroxine_grid_b5/NWA817_3

#C:/Users/nt229/Jupyter/Diamond_Data/DLS_2022-11-22_14-50-20/mg31953-3/raw/raw/Lafayette_Olivine_grid_a5/Lafayette_Olivine_2

#From September session 
#Olivine 
    #C:/Users/nt229/Jupyter/Diamond_Data/DLS_E01_9_10_Sept_22/MG30752-6 _Day1_E01_Sept22/A5_Lafayatte_Olivine/SI data (2)
    #C:/Users/nt229/Jupyter/Diamond_Data/DLS_E01_9_10_Sept_22/MG30752-6 _Day1_E01_Sept22/A5_Lafayatte_Olivine/SI_data_(1)
##will not plot these as EDS Spectrum is not an image, it is a 1D spectrum ## 
#Pyroxene
    #C:/Users/nt229/Jupyter/Diamond_Data/DLS_E01_9_10_Sept_22/MG30752-6 _Day1_E01_Sept22/B5_NWA817_pyroxene/SI data (3)
    #C:/Users/nt229/Jupyter/Diamond_Data/DLS_E01_9_10_Sept_22/MG30752-6 _Day1_E01_Sept22/B5_NWA817_pyroxene/SI data (4)
    #C:/Users/nt229/Jupyter/Diamond_Data/DLS_E01_9_10_Sept_22/MG30752-6 _Day1_E01_Sept22/B5_NWA817_pyroxene/SI data (5)
##will not plot these as EDS Spectrum is not an image, it is a 1D spectrum ##

# %%
#print file list in path fn
fn = 'C:/Users/nt229/Jupyter/Diamond_Data/DLS_2022-11-22_14-50-20/mg31953-3/raw/raw/Lafayette_Olivine_grid_a5/Lafayette_Olivine_2/'
file_list = os.listdir(fn)
n =0
for this_file in file_list:
    print(n , this_file)
    n+=1
# Out:
# 0 (2) Spectrum of EDS Spectrum Image.dm4
# 1 BF Image.dm4
# 2 EDS Spectrum Image.dm4
# 3 HAADF Image (SI Survey).dm4
# 4 HAADF Image.dm4

# %%
#Load HAADF images, EDS

# Name images
HAADF_fn_SI = fn + file_list[3] #SI Survey
HAADF_fn = fn + file_list[4] #HAADF image

# Load images
HAADF_SI = hs.load(HAADF_fn_SI)
HAADF = hs.load(HAADF_fn)

# Name EDS spectrum
SI_fn = fn +file_list[2]

#Load EDS spectra
SI = hs.load(SI_fn)

# %%
SI
# Out:
# <EDSTEMSpectrum, title: EDS Spectrum Image, dimensions: (30, 30|2048)>

# %%
SI.metadata.Acquisition_instrument.TEM
# Out:
# ├── Detector
# │   └── EDS
# │       ├── azimuth_angle = 0.0
# │       ├── elevation_angle = 40.0
# │       └── energy_resolution_MnKa = 130.0
# ├── Stage
# │   ├── tilt_alpha = 9.239999771118164
# │   ├── tilt_beta = 4.239999771118164
# │   ├── x = -0.22517900000000002
# │   ├── y = 0.17475129687500002
# │   └── z = 0.0981463984375
# ├── acquisition_mode = STEM
# ├── beam_current = 0.0
# ├── beam_energy = 200.0
# ├── camera_length = 30.0
# ├── magnification = 100000.0
# └── microscope = JEM-ARM200F

# %%
# Plot images
HAADF_SI.plot()
#HAADF.plot()
# Out:
# <img src="data:image/png;base64,..." width="639.9999630089984">

# %%
SI.plot()
# Out:
# <img src="data:image/png;base64,..." width="639.9999630089984">
# <img src="data:image/png;base64,..." width="639.9999630089984">

# %%
SI.metadata
# Out:
# ├── Acquisition_instrument
# │   └── TEM
# │       ├── Detector
# │       │   └── EDS
# │       │       ├── azimuth_angle = 0.0
# │       │       ├── elevation_angle = 40.0
# │       │       └── energy_resolution_MnKa = 130.0
# │       ├── Stage
# │       │   ├── tilt_alpha = 9.239999771118164
# │       │   ├── tilt_beta = 4.239999771118164
# │       │   ├── x = -0.22517900000000002
# │       │   ├── y = 0.17475129687500002
# │       │   └── z = 0.0981463984375
# │       ├── acquisition_mode = STEM
# │       ├── beam_current = 0.0
# │       ├── beam_energy = 200.0
# │       ├── camera_length = 30.0
# │       ├── magnification = 100000.0
# │       └── microscope = JEM-ARM200F
# ├── General
# │   ├── FileIO
# │   │   └── 0
# │   │       ├── hyperspy_version = 1.7.5
# │   │       ├── io_plugin = hyperspy.io_plugins.digital_micrograph
# │   │       ├── operation = load
# │   │       └── timestamp = 2023-05-26T09:33:33.067300+01:00
# │   ├── authors = MES
# │   ├── date = 2022-11-18
# │   ├── original_filename = EDS Spectrum Image.dm4
# │   ├── time = 12:46:57
# │   └── title = EDS Spectrum Image
# └── Signal
#     ├── Noise_properties
#     │   └── Variance_linear_model
#     │       ├── gain_factor = 1.0
#     │       └── gain_offset = 0.0
#     ├── quantity = X-rays (Counts)
#     └── signal_type = EDS_TEM

# %%
#eds maps - single colorbar
eds_maps = SI.get_lines_intensity(['Al_Ka', 'Ca_Ka', 'Fe_Ka', 'Mg_Ka', 'O_Ka', 'Si_Ka']) #'Ti_Ka'
hs.plot.plot_images(eds_maps, axes_decor = 'off', scalebar = 'all',
    tight_layout = True, cmap = 'gist_heat',
    colorbar = 'single',  
    scalebar_color = 'w', suptitle_fontsize = 8,
    padding={'top':0.8, 'bottom':0.10, 'left':0.05,
            'right':0.85, 'wspace':0.20, 'hspace':0.20});

#eds maps - multiple colorbar
eds_maps = SI.get_lines_intensity(['Al_Ka', 'Ca_Ka', 'Fe_Ka', 'Mg_Ka', 'O_Ka', 'Si_Ka']) #'Ti_Ka'
hs.plot.plot_images(eds_maps, axes_decor = 'off', scalebar = 'all',
    tight_layout = True, cmap = ['gist_heat'],
    colorbar = 'multi',  
    scalebar_color = 'w', suptitle_fontsize = 8,
    padding={'top':0.8, 'bottom':0.10, 'left':0.05,
            'right':0.85, 'wspace':0.20, 'hspace':0.20});

ax_maps = plt.gca();
#ax_maps.set_title('')
#fig4_caption="EDX spectrum images";
#txt = plt.figtext(0.5, 0.000, fig4_caption, wrap=True, horizontalalignment='center', fontsize=12);

#plt.savefig('', dpi = 300) #set folder for save

#Print HAADFs images

survey_fig = HAADF_SI.plot(colorbar = False, )

#get SI region
SI_area = SI.original_metadata['ImageList']['TagGroup0']['ImageTags']['SI']['Acquisition']['Survey Image']['Spectrum Image Rect']
#print(si_area)
#convert from px to nm
SI_area = tuple([HAADF_SI.axes_manager['x'].scale*x for x in SI_area])
#print(si_area)
#define marker on survey scan
m = hs.plot.markers.rectangle(x1= SI_area[1], y1= SI_area[0], x2= SI_area[3], y2= SI_area[2],
                                  color='yellow', linewidth = 2)
#add marker
s = HAADF_SI.add_marker(m)
# Out:
# <img src="data:image/png;base64,..." width="639.9999630089984">
# C:\Users\nt229\AppData\Local\hyperspy-bundle\lib\site-packages\hyperspy\drawing\utils.py:1191: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0, 0, 0.9, 1])
# <img src="data:image/png;base64,..." width="639.9999630089984">
# <img src="data:image/png;base64,..." width="639.9999630089984">

# %%
SI.plot()
# Out:
# <img src="data:image/png;base64,..." width="639.9999630089984">
# <img src="data:image/png;base64,..." width="639.9999630089984">

# %%
#SI_set_elements([])
#SI_set_lines([])
#SI_add_elements(['Fe', 'Si', 'Mg', 'O', 'Mn', 'Ca'])
#SI_add_lines()

SI_sum = SI.sum()
SI_sum.plot()
# Out:
# <img src="data:image/png;base64,..." width="639.9999630089984">

# %%
SI_sum.add_elements(['Fe'])
SI_sum.add_lines(['Fe_Ka'])
SI_sum.plot(True)
plt.xlim([6.0, 6.8])
#plt.ylim([0, 500])
# Out:
# <img src="data:image/png;base64,..." width="639.9999630089984">
# (6.0, 6.8)

# %%
#fit to Fe peak
SI_sum_Fe = SI_sum.isig[6.0:6.8]
SI_sum_Fe.plot(True)
m_Fe = SI_sum_Fe.create_model()
real_Fe_pos = m_Fe.components.Fe_Ka.centre.get()['value'] # get expected Fe position
m_Fe.fix_background() # set background to zero
m_Fe.free_xray_lines_energy()
m_Fe.free_xray_lines_width
results = m_Fe.fit()
# Out:
# <img src="data:image/png;base64,..." width="639.9999630089984">
# C:\Users\nt229\AppData\Local\Temp\ipykernel_11244\1078485059.py:5: DeprecationWarning: use "HasTraits.trait_get" instead
#   real_Fe_pos = m_Fe.components.Fe_Ka.centre.get()['value'] # get expected Fe position

# %%
m_Fe.plot()
meas_Fe_pos = m_Fe.components.Fe_Ka.centre.get()['value']#get measured Fe position
print('expected Fe pos : ' , real_Fe_pos)
print('measured Fe pos : ' , meas_Fe_pos)
offset_Fe =  real_Fe_pos - meas_Fe_pos 
print('offset : ' ,offset_Fe)
# Out:
# <img src="data:image/png;base64,..." width="639.9999630089984">
# expected Fe pos :  6.4039
# measured Fe pos :  6.4467343613742845
# offset :  -0.04283436137428431
# C:\Users\nt229\AppData\Local\Temp\ipykernel_11244\414576397.py:2: DeprecationWarning: use "HasTraits.trait_get" instead
#   meas_Fe_pos = m_Fe.components.Fe_Ka.centre.get()['value']#get measured Fe position

# %%
#set offset to data and check
#set offset to full data 
SI.axes_manager[-1].offset = SI.axes_manager[-1].offset + offset_Fe
SI_sum = SI.sum()
SI_sum.add_elements(['Fe'])
SI_sum.plot(True)

#Axis management
ax_spec = plt.gca()

ax_spec.set_xlim([0.0, 10.0])
ax_spec.set_title('EDS sum')
ax_spec.set_xlabel('Energy (keV)')
ax_spec.set_ylabel('X-rays (Counts)')
# Out:
# <img src="data:image/png;base64,..." width="639.9999630089984">
# Text(29.222222222222214, 0.5, 'X-rays (Counts)')

# %%
#find peaks, play with parameters to get good output
P = SI_sum.find_peaks1D_ohaver(amp_thresh= 15,medfilt_radius=21, maxpeakn=40)[0]
peak_list = []
for this_P in P:
    #print(this_P['position'])
    peak_list.append(hs.eds.get_xray_lines_near_energy(this_P['position'],width = 0.1,  only_lines=['Ka', 'Kb']),)
    print(this_P, ' : ', peak_list[-1])
# Out:
# [########################################] | 100% Completed | 115.71 ms
# (0.511419, 30.33535137, 0.17863496)  :  ['O_Ka']
# (0.69535892, 16.22650145, 0.19401784)  :  ['F_Ka']
# (0.85953212, 5.35582198, nan)  :  ['Ne_Kb', 'Ne_Ka']
# (0.92555948, 6.05724955, 0.32823887)  :  []
# (1.2437341, 16.52093739, 0.19838571)  :  ['Mg_Ka']
# (1.73529437, 22.38749922, 0.18620443)  :  ['Si_Ka']
# (1.96434352, 4.37074331, nan)  :  ['P_Ka']
# (1.99754338, 4.53165262, 0.33932877)  :  ['P_Ka']
# (2.1218927, 4.55201248, 0.41499513)  :  ['P_Kb']
# (2.29475027, 4.6013738, 0.3419084)  :  ['S_Ka']
# (2.37037231, 5.37252039, 0.9252973)  :  []
# (2.38618946, 4.69495898, 0.4254872)  :  []
# (2.39377561, 4.28544014, 0.50328045)  :  []
# (2.43617673, 4.26761725, nan)  :  ['S_Kb']
# (2.51105446, 4.12308415, nan)  :  ['S_Kb']
# (2.6684635, 3.95471422, nan)  :  ['Cl_Ka']
# (2.90516392, 4.23058536, 0.25110491)  :  []
# (2.94912826, 4.09545819, nan)  :  ['Ar_Ka']
# (3.48048823, 3.93129219, nan)  :  []
# (3.51697875, 4.00635969, nan)  :  []
# (3.64900102, 4.86043524, 0.49459015)  :  ['Ca_Ka']
# (4.01257391, 4.0599457, nan)  :  ['Ca_Kb']
# (4.03630952, 4.11028379, 1.1097897)  :  ['Ca_Kb']
# (4.10924105, 4.27272628, 0.34793866)  :  ['Sc_Ka']
# (4.22231531, 4.00985407, 0.3196743)  :  []
# (4.54307324, 4.23155295, nan)  :  ['Ti_Ka']
# (4.55309671, 4.30553412, nan)  :  ['Ti_Ka']
# (4.63947414, 4.70537724, 0.37992864)  :  []
# (4.69217425, 4.65535176, 0.21573111)  :  []
# (4.73552192, 8.69453585, 1.51777064)  :  []
# (5.18045427, 4.11850367, 0.66776943)  :  []
# (5.38328005, 4.84069395, 0.2548914)  :  ['Cr_Ka', 'V_Kb']
# (5.41224472, 4.87294642, 0.30900614)  :  ['Cr_Ka', 'V_Kb']
# (5.90896387, 6.76842536, 0.28586987)  :  ['Mn_Ka', 'Cr_Kb']
# (6.40348199, 31.93667985, 0.24032129)  :  ['Fe_Ka']
# (7.04284633, 13.72162246, 0.30317571)  :  ['Fe_Kb']
# (7.47948954, 4.01591477, 0.2194043)  :  ['Ni_Ka']
# (8.04929767, 15.81984547, 0.25811417)  :  ['Cu_Ka']
# (8.91269021, 7.63605098, 0.25026368)  :  ['Cu_Kb']
# (9.26554185, 4.38206261, 0.16519854)  :  ['Ga_Ka']
# C:\Users\nt229\AppData\Local\hyperspy-bundle\lib\site-packages\scipy\signal\_signaltools.py:1545: UserWarning: kernel_size exceeds volume extent: the volume will be zero-padded.
#   warnings.warn('kernel_size exceeds volume extent: the volume will be '

# %%
#clear peaks 
SI_sum.metadata['Sample']['elements'] = []
SI_sum.metadata['Sample'][' xray_lines '] = []

# %%
#add lines to SI_sum object
for these_peaks in peak_list:
    #print(these_peaks)
    SI_sum.add_lines(these_peaks)
SI_sum.plot(True)

ax_spec = plt.gca()

ax_spec.set_xlim([0.0, 10.0])
ax_spec.set_title('EDS sum')
ax_spec.set_xlabel('Energy (keV)')
ax_spec.set_ylabel('X-rays (Counts)')
# Out:
# <img src="data:image/png;base64,..." width="639.9999630089984">
# Text(29.222222222222214, 0.5, 'X-rays (Counts)')

# %%
SI.set_elements([])
SI.set_lines([])
SI.add_elements(['Fe', 'Si', 'Mg', 'O', 'Ca', 'Mn', 'Cr', 'Ti', 'Al']) #olivine
#SI.add_elements(['Fe', 'Si', 'Mg', 'O', 'Ca', 'Mn', 'Cr', 'Ti', 'Na', 'Ni']) #pyroxene

#SI.add_elements(['Fe', 'Si', 'Mg', 'O', 'Ca', 'Mn', 'Cr', 'Al', 'Ti', 'Ni', 'Cu', 'F', 'Na'])

#potentially all the non-zero intensities
#SI.add_elements(['Fe', 'Si', 'Mg', 'O', 'Ca', 'Mn', 'Cr', 'Al', 'Ti', 'Ni', 'Cu', 'F', 'Ne', 'P', 'S', 'Cl', 'Ar', 'Ga'])

SI.add_lines()

# %%
SI.metadata
# Out:
# ├── Acquisition_instrument
# │   └── TEM
# │       ├── Detector
# │       │   └── EDS
# │       │       ├── azimuth_angle = 0.0
# │       │       ├── elevation_angle = 40.0
# │       │       └── energy_resolution_MnKa = 130.0
# │       ├── Stage
# │       │   ├── tilt_alpha = 9.239999771118164
# │       │   ├── tilt_beta = 4.239999771118164
# │       │   ├── x = -0.22517900000000002
# │       │   ├── y = 0.17475129687500002
# │       │   └── z = 0.0981463984375
# │       ├── acquisition_mode = STEM
# │       ├── beam_current = 0.0
# │       ├── beam_energy = 200.0
# │       ├── camera_length = 30.0
# │       ├── magnification = 100000.0
# │       └── microscope = JEM-ARM200F
# ├── General
# │   ├── FileIO
# │   │   └── 0
# │   │       ├── hyperspy_version = 1.7.5
# │   │       ├── io_plugin = hyperspy.io_plugins.digital_micrograph
# │   │       ├── operation = load
# │   │       └── timestamp = 2023-05-26T09:33:33.067300+01:00
# │   ├── authors = MES
# │   ├── date = 2022-11-18
# │   ├── original_filename = EDS Spectrum Image.dm4
# │   ├── time = 12:46:57
# │   └── title = EDS Spectrum Image
# ├── Sample
# │   ├── elements = ['Al', 'Ca', 'Cr', 'Fe', 'Mg', 'Mn', 'O', 'Si', 'Ti']
# │   └── xray_lines = ['Al_Ka', 'Ca_Ka', 'Cr_Ka', 'Fe_Ka', 'Mg_Ka', 'Mn_Ka', 'O_Ka', 'Si_Ka', 'Ti_Ka']
# └── Signal
#     ├── Noise_properties
#     │   └── Variance_linear_model
#     │       ├── gain_factor = 1.0
#     │       └── gain_offset = 0.0
#     ├── quantity = X-rays (Counts)
#     └── signal_type = EDS_TEM

# %%
m = SI.sum().isig[0.0:10.0].create_model()
m.add_family_lines(['Cu_Ka', 'Al_Ka', 'Na_Ka', 'Mn_Ka', 'Cr_Ka', 'Ni_Ka', 'C_Ka', 'Ne_Ka', 'F_Ka']) #included in curve fitting but not in the final quantification

# %%
m.xray_lines
print (m.xray_lines)
# Out:
# [<Al_Ka (Gaussian component)>, <Ca_Ka (Gaussian component)>, <Ca_La (Gaussian component)>, <Cr_Ka (Gaussian component)>, <Cr_La (Gaussian component)>, <Fe_Ka (Gaussian component)>, <Fe_La (Gaussian component)>, <Mg_Ka (Gaussian component)>, <Mn_Ka (Gaussian component)>, <Mn_La (Gaussian component)>, <O_Ka (Gaussian component)>, <Si_Ka (Gaussian component)>, <Ti_Ka (Gaussian component)>, <Ti_La (Gaussian component)>, <Cu_Ka (Gaussian component)>, <Na_Ka (Gaussian component)>, <Ni_Ka (Gaussian component)>, <C_Ka (Gaussian component)>, <Ne_Ka (Gaussian component)>, <F_Ka (Gaussian component)>]

# %%
m.fit()
# Out:
#    covar: array([[ 6.31901447e+02, -1.37768166e+03,  9.79880349e+02,
#         -3.15799796e+02,  5.08657728e+01, -3.99356817e+00,
#          1.21714033e-01,  7.79892874e+00, -4.93421318e+00,
#         -8.08674636e+00,  5.55410268e+00, -4.82790022e+00,
#          1.75466766e+00, -3.40289325e+00,  6.95125459e+00,
#          4.60062494e+00, -3.14577824e+00, -2.40873537e+00,
#          6.93811546e+00,  9.45186730e-01, -9.43418082e+00,
#         -4.84196980e+00,  4.28034745e+00, -5.74699721e+00,
#         -1.76237322e+01, -2.20595176e-03, -8.25466199e-01],
#        [-1.37768166e+03,  5.24565743e+03, -4.51844307e+03,
#          1.60652038e+03, -2.74685200e+02,  2.24481301e+01,
#         -7.04118996e-01, -6.09665528e+01,  2.90407972e+01,
#          1.29078110e+00, -3.97173555e+01, -1.27997792e+01,
#         -7.26211816e+00, -5.09030419e+01, -7.11351181e+01,
#         -2.90581264e+01, -1.34478785e+01, -7.78657245e+00,
#         -4.35525559e+01, -1.43888681e+01, -6.03634669e+00,
#          3.15001631e+01, -7.24931572e+01,  4.10503649e+01,
#          1.79520626e+01, -6.47299051e+01,  1.81385150e+00],
#        [ 9.79880349e+02, -4.51844307e+03,  4.15462162e+03,
#         -1.53468676e+03,  2.69284345e+02, -2.24261507e+01,
#          7.13658746e-01,  5.06421666e+01, -2.50609908e+01,
#          4.52873927e+00,  4.40206334e+01,  1.66156500e+01,
#          3.42034609e+00,  5.38767759e+01,  6.34428405e+01,
#          2.91173437e+01,  1.60002015e+01,  9.64363352e+00,
#          3.17346426e+01,  2.23262240e+01,  1.30142228e+01,
#         3.82320649e+02, -8.16352347e+02,  2.03645375e+03])

# %%
m.fit_background(start_energy=0.0, end_energy=10.0)

# %%
m.calibrate_energy_axis(calibrate='resolution', xray_lines=['Fe_Ka']) #reference peak/given that we have Fe_Ka

# %%
m.calibrate_energy_axis(calibrate='offset', xray_lines=['Fe_Ka'])

# %%
#m.calibrate_energy_axis(calibrate='scale')

# %%
print(SI.metadata.Acquisition_instrument.TEM.Detector.EDS.energy_resolution_MnKa)
# Out:
# 130.0

# %%
m.calibrate_xray_lines(xray_lines=['Fe_Ka'])

# %%
m.multifit(iterpath='serpentine')

# %%
m.plot(xray_lines = True)
# Out:
# <img src="data:image/png;base64,..." width="639.9999630089984">

# %%
intensity = m.get_lines_intensity( xray_lines = ('Ca_Ka', 'Fe_Ka', 'Mg_Ka', 'O_Ka', 'Si_Ka', 'Mn_Ka', 'Cr_Ka', 
                                                'Ti_Ka'), plot_result = True ) #olivine

#intensity = m.get_lines_intensity( xray_lines = ('Ca_Ka', 'Fe_Ka', 'Mg_Ka', 'O_Ka', 'Si_Ka', 'Mn_Ka', 'Cr_Ka', 
                                               # 'Ti_Ka'), plot_result = True ) #pyroxene

#intensity = m.get_lines_intensity( xray_lines = ('Ca_Ka', 'Fe_Ka', 'Mg_Ka', 'O_Ka', 'Si_Ka', 'Mn_Ka', 'Cr_Ka', 'Ni_Ka', 
                                                 #'Cu_Ka', 'Al_Ka', 'F_Ka','Ti_Ka', 'Na_Ka'), plot_result = True )
#intensity = m.get_lines_intensity( xray_lines = ('Ca_Ka', 'Fe_Ka', 'Mg_Ka', 'O_Ka', 'Si_Ka', 'Mn_Ka', 'Cr_Ka', 'Ni_Ka', 
                                                #'Cu_Ka', 'Al_Ka', 'F_Ka','Ti_Ka', 'Ne_Ka', 'P_Ka', 'S_Ka', 'Cl_Ka', 
                                                 #'Ar_Ka', 'Ga_Ka'), plot_result = True )
# Out:
# Ca_Ka at 3.6917 keV : Intensity = 185.30
# Fe_Ka at 6.4039 keV : Intensity = 48253.87
# Mg_Ka at 1.2536 keV : Intensity = 6894.91
# O_Ka at 0.5249 keV : Intensity = 20998.03
# Si_Ka at 1.7397 keV : Intensity = 14914.60
# Mn_Ka at 5.8987 keV : Intensity = 911.98
# Cr_Ka at 5.4147 keV : Intensity = 202.03
# Ti_Ka at 4.5109 keV : Intensity = 116.58

# %%
intensity
# Out:
# [<BaseSignal, title: Intensity of Ca_Ka at 3.69 keV from EDS Spectrum Image, dimensions: (1|)>,
#  <BaseSignal, title: Intensity of Fe_Ka at 6.40 keV from EDS Spectrum Image, dimensions: (1|)>,
#  <BaseSignal, title: Intensity of Mg_Ka at 1.25 keV from EDS Spectrum Image, dimensions: (1|)>,
#  <BaseSignal, title: Intensity of O_Ka at 0.52 keV from EDS Spectrum Image, dimensions: (1|)>,
#  <BaseSignal, title: Intensity of Si_Ka at 1.74 keV from EDS Spectrum Image, dimensions: (1|)>,
#  <BaseSignal, title: Intensity of Mn_Ka at 5.90 keV from EDS Spectrum Image, dimensions: (1|)>,
#  <BaseSignal, title: Intensity of Cr_Ka at 5.41 keV from EDS Spectrum Image, dimensions: (1|)>,
#  <BaseSignal, title: Intensity of Ti_Ka at 4.51 keV from EDS Spectrum Image, dimensions: (1|)>]

# %%
#Quantification
#imput K factors corresponding to elements in SI and calculate atomic percent 
#kfactors = [0.74, 0.91, 0.99, 1.0, 0.97, 1.3, 1.1, 0.85] 

#kfactors = [0.74, 0.91, 0.99, 1.0, 0.97, 1.1, 1.1, 1.3, 1.1, 0.85] 

#all possible elements 
#kfactors = [1.0, 0.79, 0.74, 1.1, 0.91, 1.2, 1.2, 0.99, 1.4, 1.0, 0.97, 1.1, 1.1, 1.3, 1, 1.1, 1.1, 0.85] 

#kfactors = [ 0.7, 0.92, 1.2, 0.83, 0.92, 1.3, 1.1, 0.8] #for Olivine with Al
#kfactors = [0.7, 0.82, 1.08, 1.22, 0.98, 1.3, 1.1, 0.82] #pyroxene

atomic_percent = SI.sum().quantification(intensities= intensity, method='CL',
                                  factors=kfactors)

#need to try adjusting K factors to see how they change %s and the Mg#

kfactors = [0.7, 0.82, 1.08, 1.22, 0.98, 1.3, 1.1, 0.82] #for Olivine to give 1:2
#kfactors = [0.7, 0.82, 1.08, 1.22, 0.98, 1.1, 1.1, 1.3, 1.1, 0.82] #pyroxene
# Out:
# [########################################] | 100% Completed | 121.93 ms

# %%
#print the total atomic percent over the whole image/region
sum_atomic_percent = []
for this_atom in atomic_percent:
    print(this_atom.metadata['General']['title'], ':',  this_atom.mean().data[0])
    sum_atomic_percent.append(this_atom.mean().data[0])
# Out:
# atomic percent of Ca : 0.10217230191551754
# atomic percent of Fe : 22.36834375072104
# atomic percent of Mg : 9.672278301363315
# atomic percent of O : 50.54832383717262
# atomic percent of Si : 16.42962069688875
# atomic percent of Mn : 0.6812832082080589
# atomic percent of Cr : 0.13493152545196213
# atomic percent of Ti : 0.06304637827872613

# %%
#add all to check is equal to 100
sum(sum_atomic_percent)
# Out:
# 99.99999999999997

# %%
#print (atomic_percent)

# %%
weight_percent = SI.sum().quantification(intensities=intensity, method='CL',
                                  factors=kfactors, composition_units='weight')

#print the total weight percent over the whole image
sum_weight_percent = []
for this_atom in weight_percent:
    print(this_atom.metadata['General']['title'], ':',  this_atom.mean().data[0])
    sum_weight_percent.append(this_atom.mean().data[0])
# Out:
# weight percent of Ca : 0.1459334430671826
# weight percent of Fe : 44.51780405718897
# weight percent of Mg : 8.377993508956132
# weight percent of O : 28.822129525190594
# weight percent of Si : 16.444675469226663
# weight percent of Mn : 1.3338791857617667
# weight percent of Cr : 0.25003442717693836
# weight percent of Ti : 0.1075503834317306

# %%
sum(sum_weight_percent)
# Out:
# 99.99999999999999

# %%
#calculating cation ratios
#calculating Mg number (cation ratio)
Mg_ratio = (sum_atomic_percent [(2)]/(sum_atomic_percent [(0)]+sum_atomic_percent [(1)]
                                      + sum_atomic_percent [(2)]))*100

#calculating Fe number (cation ratio)
Fe_ratio = (sum_atomic_percent [(1)]/(sum_atomic_percent [(0)]+sum_atomic_percent [(1)]
                                      + sum_atomic_percent [(2)]))*100

#calculating Ca number (cation ratio)
Ca_ratio = (sum_atomic_percent [(0)]/(sum_atomic_percent [(0)]+sum_atomic_percent [(1)]
                                      + sum_atomic_percent [(2)]))*100


print('Mg ratio :' , Mg_ratio, ',', 
      'Fe ratio :', Fe_ratio, ',', 
      'Ca ratio :', Ca_ratio)
# Out:
# Mg ratio : 30.091591274981017 , Fe ratio : 69.59053872034467 , Ca ratio : 0.3178700046743234

# %%
Mg_number = (sum_atomic_percent [(2)]/(sum_atomic_percent [(1)]
                                      + sum_atomic_percent [(2)]))*100
print('Mg number :' , Mg_number)
# Out:
# Mg number : 30.187548436607525

# %%
###########

# %%
from prettytable import PrettyTable
 
# Specify the Column Names while initializing the Table
myTable = PrettyTable(["Oxide", "Oxide wt%", "Molec. wt", "Prop of Oxides", "O #", "O atomic prop.", 
                       "Normal. factor", "Anions", "O per cation", "Cations"])
 
# Add rows
myTable.add_row(["SiO2", (round(sum_weight_percent[4],2)), "60.074", "0.530179", "2", "1.060368", "1.90543", "2.02043", "2", "1.0102"])
myTable.add_row(["FeO", (round(sum_weight_percent[1],2)), "71.841", "0.816247", "1", "0.816247", "1.90543", "1.5553", "1", "1.5553" ])
myTable.add_row(["MnO", (round(sum_weight_percent[4],2)), "70.937", "0.011982", "1", "0.011982", "1.90543", "0.02283", "1", "0.02283"])
myTable.add_row(["MgO", (round(sum_weight_percent[2],2)), "40.299", "0.110675", "1", "0.110675", "1.90543", "0.03142", "1",  "0.03142" ])
myTable.add_row(["CaO", (round(sum_weight_percent[0],2)), "56.077", "0.1", "1", "0.1", "1.90543", "0.01", "1", "0.01"])
myTable.add_row(["Al2O3", "0.00", "101.96", "0.0", "3", "0.0", "1.90543", "0.0", "1", "0.0"])
 
print(myTable)
# Out:
# +-------+-----------+-----------+----------------+-----+----------------+----------------+---------+--------------+---------+
# | Oxide | Oxide wt% | Molec. wt | Prop of Oxides | O # | O atomic prop. | Normal. factor |  Anions | O per cation | Cations |
# +-------+-----------+-----------+----------------+-----+----------------+----------------+---------+--------------+---------+
# |  SiO2 |   14.42   |   60.074  |    0.530179    |  2  |    1.060368    |    1.90543     | 2.02043 |      2       |  1.0102 |
# |  FeO  |   37.78   |   71.841  |    0.816247    |  1  |    0.816247    |    1.90543     |  1.5553 |      1       |  1.5553 |
# |  MnO  |   14.42   |   70.937  |    0.011982    |  1  |    0.011982    |    1.90543     | 0.02283 |      1       | 0.02283 |
# |  MgO  |    7.2    |   40.299  |    0.110675    |  1  |    0.110675    |    1.90543     | 0.03142 |      1       | 0.03142 |
# |  CaO  |    0.22   |   56.077  |      0.1       |  1  |      0.1       |    1.90543     |   0.01  |      1       |   0.01  |
# | Al2O3 |    0.00   |   101.96  |      0.0       |  3  |      0.0       |    1.90543     |   0.0   |      1       |   0.0   |
# +-------+-----------+-----------+----------------+-----+----------------+----------------+---------+--------------+---------+
